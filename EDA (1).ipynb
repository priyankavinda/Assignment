# %%
# load the purchase data

# %%
import numpy as np
import pandas as pd
import os
import io
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uplaoded = files.upload()
# Out:
#      <input type="file" id="files-9316f119-a916-425e-9725-cc533f4881ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9316f119-a916-425e-9725-cc533f4881ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv(io.BytesIO(uplaoded['train (1).csv']))

# %%
data.sample(2).T
# Out:
#                                43753      348234
# User_ID                       1000752    1005636
# Product_ID                  P00194642  P00107642
# Gender                              F          M
# Age                             26-35      26-35
# Occupation                          3          7
# City_Category                       A          A
# Stay_In_Current_City_Years          3          0
# Marital_Status                      0          1
# Product_Category_1                  1          5
# Product_Category_2                6.0        NaN
# Product_Category_3               13.0        NaN
# Purchase                         8320       7131

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data.isna().sum()/len(data)*100
# Out:
# User_ID                        0.000000
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.566643
# Product_Category_3            69.672659
# Purchase                       0.000000
# dtype: float64

# %% [markdown]
# ##### if the data is large and having so much null value as above then drop the null values.like porduct_cat 3

# %%
# drop Product_Category_3
# Drop NA
data.drop('Product_Category_3', axis=1, inplace=True)

# %%
data.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Purchase
# 0                 NaN      8370
# 1                 6.0     15200

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      0
# dtype: int64

# %%
# Q1:purchase by gender
# Q2:purchase by category 2 and 3
# Q3:Total purchase by gender and age

# %%
data.shape
# Out:
# (376430, 11)

# %%
data.groupby('Gender')['Purchase'].sum().reset_index()
# Out:
#   Gender    Purchase
# 0      F   857585124
# 1      M  2932696388

# %%
summary= data.groupby('Gender')['Purchase'].sum().reset_index()

# %%
summary['Purchase']/10**6
# Out:
# 0     857.585124
# 1    2932.696388
# Name: Purchase, dtype: float64

# %% [markdown]
# Female is buying  857.585124 USD

# %%
data.groupby('Gender').agg(
Distinct_count_user = ('User_ID','nunique')).reset_index()
# Out:
#   Gender  Distinct_count_user
# 0      F                 1666
# 1      M                 4225

# %%
summary_1= data.groupby('Gender')['Purchase'].mean().reset_index()
summary_1
# Out:
#   Gender      Purchase
# 0      F   9369.443068
# 1      M  10293.774616

# %%
summary_2= data.groupby('Product_Category_1')['Purchase'].sum().reset_index()

# %%
summary_2.sort_values(by=)
# Out:
#   File "<ipython-input-21-d7b20f841b57>", line 1
#     summary_2.sort_values(by=)
#                              ^
# SyntaxError: invalid syntax
